# %%
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path='C:\\Users\\Bishwajit\\Desktop\\chromedriver.exe')

# %%
full_url ='https://play.google.com/store/apps/details?id=com.mw.rouletteroyale&showAllReviews=true'
driver.get(full_url)

# %%
text=['Review']
author=['Author']
help1=['Helpfulness']
date=['Date']
rate=['Rating']

# %%
# SCROLL_PAUSE_TIME = 5
 
# # Get scroll height
# last_height = driver.execute_script("return document.body.scrollHeight")
# time.sleep(SCROLL_PAUSE_TIME)
 
# while True:
#     # Scroll down to bottom
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
 
#     # Wait to load page
#     time.sleep(SCROLL_PAUSE_TIME)
 
#     # Calculate new scroll height and compare with last scroll height
#     new_height = driver.execute_script("return document.body.scrollHeight")
#     if new_height == last_height:
#         break
#     last_height = new_height

# %%
import requests as rq
driver.get(full_url)
soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        
author_sec = soup.find_all("span","X43Kjb")
for r in author_sec[2:]:
    author.append(r.text)
Review_text_sec = soup.find_all("div",'UD7Dzf')
for t in Review_text_sec:
    text.append(t.text)

Date_sec = soup.find_all(attrs={"class": "p2TkOb"})    
for d in Date_sec:
    da = d.text
    date.append(da)
help_sec = soup.find_all(attrs={"class": "jUL89d y92BAb"})    
for d in help_sec:
    hel = d.get_text()
    y = hel.split()
    help1.append(y[0])

# %%
Rating = soup.find_all(attrs={"div": "pf5lIe"})

for d in Rating:
    print(elem.get('aria-label'))
    rating = d.text
    y = rating.split()
    rate.append(y[0])

# %%
rate
df = pd.DataFrame([date,rate,help1,author,text]).transpose()
df
# Out:
#                     0       1            2                          3  \
# 0                Date  Rating  Helpfulness                     Author
# 1      April 25, 2021    None          186                     n ming
# 2      April 25, 2021    None           93                Ryan Davies
# 3        May 11, 2021    None           13            Mywavia Studios
# 4        May 17, 2021    None            0                Mike Culley
# 5        May 18, 2021    None           59            Sandra Ethridge
# 6        May 23, 2021    None           45                David Witts
# 7      April 16, 2021    None          101                   Pete Ens
# 8      March 25, 2021    None          188            Mywavia Studios
# 9     January 4, 2021    None            2               Ammon Allred
# 10    January 4, 2021    None            9                Geoff White
# 11   January 24, 2021    None           97              Luis Gavaldon
# ...

# %%
df.to_csv('C:\\Users\\Bishwajit\\Desktop\\reviews.csv', index=False, encoding='utf-8')
